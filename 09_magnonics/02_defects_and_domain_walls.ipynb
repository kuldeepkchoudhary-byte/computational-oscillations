# %% [markdown]
# # Defects and Domain Walls
#
# ## Theory
# Localized defects and domain walls.

# %%
import numpy as np
import matplotlib.pyplot as plt
from coupled_oscillators.magnonics import domain_wall_profile

N = 50
spins = domain_wall_profile(N, width=5.0)

plt.plot(spins[:, 2], label="Mz")
plt.plot(spins[:, 0], label="Mx")
plt.title("Domain Wall Profile")
plt.xlabel("Site index")
plt.ylabel("Spin Component")
plt.legend()
import os
os.makedirs('02_defects_and_domain_walls', exist_ok=True)
plt.savefig(f'02_defects_and_domain_walls/plot_{plt.gcf().number}.png')
plt.show()
